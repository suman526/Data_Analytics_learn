# %%
import pandas as pd

# %%
df= pd.read_csv("weatherAUS.csv")

# %%
df.head()
# Out:
#          Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0  2008-12-01   Albury     13.4     22.9       0.6          NaN       NaN
# 1  2008-12-02   Albury      7.4     25.1       0.0          NaN       NaN
# 2  2008-12-03   Albury     12.9     25.7       0.0          NaN       NaN
# 3  2008-12-04   Albury      9.2     28.0       0.0          NaN       NaN
# 4  2008-12-05   Albury     17.5     32.3       1.0          NaN       NaN
#
#   WindGustDir  WindGustSpeed WindDir9am  ... Humidity9am  Humidity3pm  \
# 0           W           44.0          W  ...        71.0         22.0
# 1         WNW           44.0        NNW  ...        44.0         25.0
# 2         WSW           46.0          W  ...        38.0         30.0
# 3          NE           24.0         SE  ...        45.0         16.0
# 4           W           41.0        ENE  ...        82.0         33.0
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# ...

# %%
#data preprocessing/data cleaning
#data:
#1. numerical
#2. categorical

# %%
# to calculate null values in the data
#-->isnull
#-->notnull-->true-->data is present
data=df.isnull() #get the value in boolean
#if data is present---> false--->else True

# %%
df.isnull().sum()
#zero means--> data is present in the column
# Out:
# Date                 0
# Location             0
# MinTemp           1485
# MaxTemp           1261
# Rainfall          3261
# Evaporation      62790
# Sunshine         69835
# WindGustDir      10326
# WindGustSpeed    10263
# WindDir9am       10566
# WindDir3pm        4228
# WindSpeed9am      1767
# WindSpeed3pm      3062
# Humidity9am       2654
# Humidity3pm       4507
# Pressure9am      15065
# Pressure3pm      15028
# Cloud9am         55888
# Cloud3pm         59358
# Temp9am           1767
# Temp3pm           3609
# RainToday         3261
# RainTomorrow      3267
# dtype: int64

# %%
#total data
df.shape
# Out:
# (145460, 23)

# %%
import seaborn as sns

# %%
sns.heatmap(data)

# %%
#data analysis
#describe data
#only on numerical data
#if range is defined then it is not numerical data
df.describe()
# Out:
#              MinTemp        MaxTemp       Rainfall   Evaporation  \
# count  143975.000000  144199.000000  142199.000000  82670.000000
# mean       12.194034      23.221348       2.360918      5.468232
# std         6.398495       7.119049       8.478060      4.193704
# min        -8.500000      -4.800000       0.000000      0.000000
# 25%         7.600000      17.900000       0.000000      2.600000
# 50%        12.000000      22.600000       0.000000      4.800000
# 75%        16.900000      28.200000       0.800000      7.400000
# max        33.900000      48.100000     371.000000    145.000000
#
#            Sunshine  WindGustSpeed   WindSpeed9am   WindSpeed3pm  \
# count  75625.000000  135197.000000  143693.000000  142398.000000
# mean       7.611178      40.035230      14.043426      18.662657
# std        3.785483      13.607062       8.915375       8.809800
# min        0.000000       6.000000       0.000000       0.000000
# ...

# %%
#how to find the relation between column of the data
#it gives you correlation coefficient(cc) 
# 1 is 100% likewise others
#diagonally 100%
#find only on numerical values
#cc is proportional if cc is positive 
# cc is inversely proportional if cc is negative
df.corr()
# Out:
#                 MinTemp   MaxTemp  Rainfall  Evaporation  Sunshine  \
# MinTemp        1.000000  0.736555  0.103938     0.466993  0.072586
# MaxTemp        0.736555  1.000000 -0.074992     0.587932  0.470156
# Rainfall       0.103938 -0.074992  1.000000    -0.064351 -0.227549
# Evaporation    0.466993  0.587932 -0.064351     1.000000  0.365602
# Sunshine       0.072586  0.470156 -0.227549     0.365602  1.000000
# WindGustSpeed  0.177415  0.067615  0.133659     0.203021 -0.034750
# WindSpeed9am   0.175064  0.014450  0.087338     0.193084  0.005499
# WindSpeed3pm   0.175173  0.050300  0.057887     0.129400  0.053834
# Humidity9am   -0.232899 -0.504110  0.224405    -0.504092 -0.490819
# Humidity3pm    0.006089 -0.508855  0.255755    -0.390243 -0.629130
# Pressure9am   -0.450970 -0.332061 -0.168154    -0.270362  0.041970
# Pressure3pm   -0.461292 -0.427167 -0.126534    -0.293581 -0.019719
# Cloud9am       0.078754 -0.289370  0.198528    -0.183793 -0.675323
# ...

# %%
#graph---> heatmap
sns.heatmap(df.corr(),annot=True)

# %%
#df.replace(to_replace="Albury",value='Agra')
#to replace

# %%
#handling missing values
#1.delete
#2.ignore
#3.store random values
#prediction with missing value<pred with not missing value
#these three---> less use

# %%
#4.mean: 
#5.median:mid value
#6.mode: highest of all value
#no mode when single repetation

# %%
#drop:to delete row and column
df.head()
# Out:
#          Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0  2008-12-01   Albury     13.4     22.9       0.6          NaN       NaN
# 1  2008-12-02   Albury      7.4     25.1       0.0          NaN       NaN
# 2  2008-12-03   Albury     12.9     25.7       0.0          NaN       NaN
# 3  2008-12-04   Albury      9.2     28.0       0.0          NaN       NaN
# 4  2008-12-05   Albury     17.5     32.3       1.0          NaN       NaN
#
#   WindGustDir  WindGustSpeed WindDir9am  ... Humidity9am  Humidity3pm  \
# 0           W           44.0          W  ...        71.0         22.0
# 1         WNW           44.0        NNW  ...        44.0         25.0
# 2         WSW           46.0          W  ...        38.0         30.0
# 3          NE           24.0         SE  ...        45.0         16.0
# 4           W           41.0        ENE  ...        82.0         33.0
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# ...

# %%
drop_data=df.drop(axis=0,columns='Evaporation')
#df.drop(['Evaporation'],axis=1)

# %%
#dropna:drop null value
dropna_data=df.dropna(axis=0)
#df.dropna: delete all the data
#do not use as it will reduce the data and you will not able ro recognise it

# %%
df.shape
# Out:
# (145460, 23)

# %%
dropna_data.shape
# Out:
# (56420, 23)

# %%
#searching and sorting
#loc and iloc:for searching 
#loc:location based searching
#iloc: index based location serching
df.loc[df['Location']=='Albury']#gives you memory address
# Out:
#             Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0     2008-12-01   Albury     13.4     22.9       0.6          NaN       NaN
# 1     2008-12-02   Albury      7.4     25.1       0.0          NaN       NaN
# 2     2008-12-03   Albury     12.9     25.7       0.0          NaN       NaN
# 3     2008-12-04   Albury      9.2     28.0       0.0          NaN       NaN
# 4     2008-12-05   Albury     17.5     32.3       1.0          NaN       NaN
# ...          ...      ...      ...      ...       ...          ...       ...
# 3035  2017-06-21   Albury      1.2     15.2       0.4          NaN       NaN
# 3036  2017-06-22   Albury      0.8     13.4       0.0          NaN       NaN
# 3037  2017-06-23   Albury      1.1     11.9       0.0          NaN       NaN
# 3038  2017-06-24   Albury      1.1     14.1       0.2          NaN       NaN
# 3039  2017-06-25   Albury      3.9     10.9       0.0          NaN       NaN
#
# ...

# %%
df.loc[df['Location']!='Albury']
# Out:
#               Date       Location  MinTemp  MaxTemp  Rainfall  Evaporation  \
# 3040    2009-01-01  BadgerysCreek     13.3     34.2       0.0          NaN
# 3041    2009-01-02  BadgerysCreek     14.7     26.1       0.0          NaN
# 3042    2009-01-03  BadgerysCreek     13.6     22.3       0.0          NaN
# 3043    2009-01-04  BadgerysCreek     17.7     31.2       0.0          NaN
# 3044    2009-01-05  BadgerysCreek     15.5     38.8       0.0          NaN
# ...            ...            ...      ...      ...       ...          ...
# 145455  2017-06-21          Uluru      2.8     23.4       0.0          NaN
# 145456  2017-06-22          Uluru      3.6     25.3       0.0          NaN
# 145457  2017-06-23          Uluru      5.4     26.9       0.0          NaN
# 145458  2017-06-24          Uluru      7.8     27.0       0.0          NaN
# 145459  2017-06-25          Uluru     14.9      NaN       0.0          NaN
#
# ...

# %%
#Use loc to search the data from df
#1.find the name and founded year of edtech companies

# %%
df_new= pd.read_csv("Indian Startup.csv")

# %%
df_new
# Out:
#          Company/Brand  Founded Headquarters  \
# 0         CollegeDekho   2015.0      Gurgaon
# 1                 BOX8   2012.0       Mumbai
# 2                Simpl   2015.0    Bangalore
# 3          8i Ventures   2018.0       Mumbai
# 4            PayGlocal   2021.0    Bangalore
# ...                ...      ...          ...
# 1204          HobSpace   2019.0       Mumbai
# 1205           DcodeAI   2020.0    New Delhi
# 1206  Biocon Biologics   1978.0    Bangalore
# 1207        KiranaKart   2020.0       Mumbai
# 1208             Meddo   2018.0      Gurgaon
#
#                                 Sector  \
# 0                           E-learning
# 1                     Food & Beverages
# 2                    Consumer Services
# 3     Venture Capital & Private Equity
# 4                   Financial Services
# ...                                ...
# 1204                            EdTech
# 1205                            EdTech
# 1206                     BioTechnology
# ...

# %%
#[]--->data will appear in series
#[[]]--> data will be in dataframe
df2=df_new.loc[df_new['Sector']=='EdTech'][['Company/Brand','Founded']]
df2

# %%
#[[]]-->to convert into dataframe
df_new[['Sector']] == 'Edtech'
# Out:
#       Sector
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
# ...      ...
# 1204   False
# 1205   False
# 1206   False
# 1207   False
# 1208   False
#
# [1209 rows x 1 columns]

# %%
#2d data length should be same
#"and" "or" will not work here as answer is getting in boolean
#here we req. bitwise operator is working not comaparative
sector=df_new.loc[(df_new['Sector']=='EdTech') | (df_new['Sector']=='E-commerce')] [['Company/Brand','Founded']]

# %%
sector.shape
# Out:
# (139, 2)

# %%
sector_m=df_new.loc[(((df_new['Sector']=='EdTech') | (df_new['Sector']=='E-commerce')) & (df_new['Headquarters']=='Mumbai')),['Company/Brand', 'Founded','Sector','Headquarters']]

# %%
sector_m
# Out:
#         Company/Brand  Founded      Sector Headquarters
# 103             Zepto   2021.0  E-commerce       Mumbai
# 295           Purplle   2012.0  E-commerce       Mumbai
# 396   Genext Students   2013.0      EdTech       Mumbai
# 516        Expertrons   2019.0      EdTech       Mumbai
# 530            upGrad   2015.0      EdTech       Mumbai
# 632       CareerNinja   2017.0      EdTech       Mumbai
# 691         SpEd@home   2020.0      EdTech       Mumbai
# 727         QuickSell   2017.0  E-commerce       Mumbai
# 771       Skillmatics   2016.0      EdTech       Mumbai
# 846          Mentoria   2015.0      EdTech       Mumbai
# 858         Klassroom   2016.0      EdTech       Mumbai
# 887            upGrad   2015.0      EdTech       Mumbai
# 888       Lead School   2012.0      EdTech       Mumbai
# 895            Taikee   2010.0  E-commerce       Mumbai
# 934           Beldara   2018.0  E-commerce       Mumbai
# 1093        Pepperfry   2011.0  E-commerce       Mumbai
# ...

# %%
sector_m.shape
# Out:
# (21, 4)

# %%
#dot notation
df_new.Sector[0:7]
# Out:
# 0                          E-learning
# 1                    Food & Beverages
# 2                   Consumer Services
# 3    Venture Capital & Private Equity
# 4                  Financial Services
# 5          Health, Wellness & Fitness
# 6                                 OTT
# Name: Sector, dtype: object

# %%
#data manipulation
#drop
#adding columns or rows
#perform aggregation function
#iloc
df_new.columns
# Out:
# Index(['Company/Brand', 'Founded', 'Headquarters', 'Sector', 'What it does',
#        'Founder/s', 'Investor/s', 'Amount', 'Stage', 'Date '],
#       dtype='object')

# %%
df_new[df_new['Founded']>2018]
# Out:
#         Company/Brand  Founded Headquarters              Sector  \
# 4           PayGlocal   2021.0    Bangalore  Financial Services
# 16    Exponent Energy   2020.0    Bangalore          Automotive
# 17           Trinkerr   2021.0    Bangalore     Capital Markets
# 18              Zorro   2021.0     Gurugram      Social network
# 19      Ultraviolette   2021.0    Bangalore          Automotive
# ...               ...      ...          ...                 ...
# 1195              Kyt   2020.0    Bangalore              EdTech
# 1196            iMumz   2019.0    Bangalore          Healthcare
# 1204         HobSpace   2019.0       Mumbai              EdTech
# 1205          DcodeAI   2020.0    New Delhi              EdTech
# 1207       KiranaKart   2020.0       Mumbai          E-commerce
#
#                                            What it does  \
# 4     PayGlocal is a FinTech solving for global paym...
# 16    Simplifying energy for EVs by building a Flexi...
# ...

# %%
#here one column will be added in the data and all the values will be same as we have took the summation of founded yr and assined to that variable
df_new['sum_of_fy'] = df_new['Founded'].sum()

# %%
df_new
# Out:
#          Company/Brand  Founded Headquarters  \
# 0         CollegeDekho   2015.0      Gurgaon
# 1                 BOX8   2012.0       Mumbai
# 2                Simpl   2015.0    Bangalore
# 3          8i Ventures   2018.0       Mumbai
# 4            PayGlocal   2021.0    Bangalore
# ...                ...      ...          ...
# 1204          HobSpace   2019.0       Mumbai
# 1205           DcodeAI   2020.0    New Delhi
# 1206  Biocon Biologics   1978.0    Bangalore
# 1207        KiranaKart   2020.0       Mumbai
# 1208             Meddo   2018.0      Gurgaon
#
#                                 Sector  \
# 0                           E-learning
# 1                     Food & Beverages
# 2                    Consumer Services
# 3     Venture Capital & Private Equity
# 4                   Financial Services
# ...                                ...
# 1204                            EdTech
# 1205                            EdTech
# 1206                     BioTechnology
# ...

# %%
df_new['new_column'] = 'hello'

# %%
df_new
# Out:
#          Company/Brand  Founded Headquarters  \
# 0         CollegeDekho   2015.0      Gurgaon
# 1                 BOX8   2012.0       Mumbai
# 2                Simpl   2015.0    Bangalore
# 3          8i Ventures   2018.0       Mumbai
# 4            PayGlocal   2021.0    Bangalore
# ...                ...      ...          ...
# 1204          HobSpace   2019.0       Mumbai
# 1205           DcodeAI   2020.0    New Delhi
# 1206  Biocon Biologics   1978.0    Bangalore
# 1207        KiranaKart   2020.0       Mumbai
# 1208             Meddo   2018.0      Gurgaon
#
#                                 Sector  \
# 0                           E-learning
# 1                     Food & Beverages
# 2                    Consumer Services
# 3     Venture Capital & Private Equity
# 4                   Financial Services
# ...                                ...
# 1204                            EdTech
# 1205                            EdTech
# 1206                     BioTechnology
# ...
